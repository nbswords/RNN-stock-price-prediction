# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from FinMind.data import DataLoader
dl=DataLoader()
data = dl.taiwan_stock_daily_adj("2330", "2018-01-01", "2021-07-02")

fig=plt.figure(figsize=(20,8))
plt.xticks(rotation = 90)  
ax1 = plt.subplot(111)
ax1.plot(data.close,color='red',label='close')
ax1.plot(data.open,color='green',label='open')
plt.legend()
# twin 為共享x軸
ax2= ax1.twinx()
plt.bar(data.date,data.Trading_Volume.astype('int')//1000)
ax3 = ax1.twinx()
# Out:
# C:\Users\desse\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   import sys

# %%
# train, test split
train_size = int(len(data) * 0.7)
test_size = len(data) - train_size
train, test = data[0:train_size], data[train_size:len(data)]

print('Training size: ', train_size)
print('Test size: ', test_size)

#只要Volume
train_set = train['Trading_Volume']
test_set = test['Trading_Volume']

# MinMaxScale
from sklearn.preprocessing import MinMaxScaler 
sc = MinMaxScaler(feature_range = (0, 1))
train_set = train_set.values.reshape(-1, 1)
training_set_scaled = sc.fit_transform(train_set)

print('training_set_scaled:\n',training_set_scaled[0:5])
# Out:
# Training size:  500
# Test size:  215
# training_set_scaled:
#  [[0.1144334 ]
#  [0.22252775]
#  [0.20252178]
#  [0.15929965]
#  [0.14445588]]

# %%
look_back=11
X_train = [] 
y_train = []
for i in range(look_back,len(train_set)):
    X_train.append(training_set_scaled[i-look_back:i-1, 0]) 
    y_train.append(training_set_scaled[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train) 
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

print('用第',look_back-1,'天之前的股價:')
print(X_train[0])
print('預測第',look_back-1,'天的股價:')
print(y_train[0])
# Out:
# 用第 10 天之前的股價:
# [[0.1144334 ]
#  [0.22252775]
#  [0.20252178]
#  [0.15929965]
#  [0.14445588]
#  [0.12225575]
#  [0.17509682]
#  [0.22541205]
#  [0.15470719]
#  [0.19774628]]
# 預測第 10 天的股價:
# 0.2733015470616637

# %%
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN

model = Sequential()
model.add(SimpleRNN(units = 100, input_shape = (X_train.shape[1], 1)))
model.add(Dense(units = 1))
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
history = model.fit(X_train, y_train, epochs = 100, batch_size = 16)

plt.title('train_loss')
plt.ylabel('loss')
plt.xlabel('Epoch')
plt.plot(history.history["loss"])
# Out:
# Epoch 1/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0293
# Epoch 2/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0163
# Epoch 3/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0156
# Epoch 4/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0146
# Epoch 5/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0147
# Epoch 6/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0146
# Epoch 7/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0152
# Epoch 8/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0159
# Epoch 9/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0140
# Epoch 10/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0141
# Epoch 11/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0143
# Epoch 12/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0143
# Epoch 13/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0142
# Epoch 14/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0141
# Epoch 15/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0139
# Epoch 16/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0139
# Epoch 17/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0140
# Epoch 18/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 19/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 20/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0136
# Epoch 21/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0140
# Epoch 22/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 23/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 24/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 25/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 26/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 27/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0137
# Epoch 28/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 29/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0139
# Epoch 30/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 31/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0142
# Epoch 32/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0136
# Epoch 33/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 34/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0139
# Epoch 35/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 36/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0139
# Epoch 37/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 38/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0138
# Epoch 39/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 40/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0136
# Epoch 41/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 42/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 43/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 44/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 45/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 46/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 47/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0136
# Epoch 48/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0139
# Epoch 49/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0136
# Epoch 50/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 51/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 52/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0136
# Epoch 53/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 54/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0136
# Epoch 55/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 56/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 57/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 58/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 59/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 60/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 61/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0146
# Epoch 62/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0139
# Epoch 63/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 64/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0139
# Epoch 65/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 66/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 67/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 68/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 69/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 70/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0139
# Epoch 71/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0136
# Epoch 72/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0136
# Epoch 73/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 74/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 75/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 76/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 77/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 78/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0136
# Epoch 79/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 80/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0139
# Epoch 81/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 82/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0139
# Epoch 83/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 84/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0136
# Epoch 85/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0135
# Epoch 86/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0139
# Epoch 87/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 88/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 89/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 90/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0140
# Epoch 91/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 92/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0136
# Epoch 93/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 94/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 95/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 96/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 97/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 98/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 99/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0138
# Epoch 100/100
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0139

# %%
dataset_total = pd.concat((train['Trading_Volume'], test['Trading_Volume']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(test) - look_back:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(look_back, len(inputs)):
    X_test.append(inputs[i-look_back:i-1, 0])

X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

predicted_stock_price = model.predict(X_test)
# inverse_transform將股價轉為歸一化前
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
# Plot prediction vs Real
plt.plot(test['Trading_Volume'].values, color = 'black', label = 'Real TSMC Stock Price')
plt.plot(predicted_stock_price, color = 'green', label = 'Predicted TSMC Stock Price')
plt.title('TSMC Stock Price Prediction')
plt.xlabel('Time',size=14)
plt.ylabel('Stock Price',size=14)
plt.legend(fontsize=14)
plt.show()
